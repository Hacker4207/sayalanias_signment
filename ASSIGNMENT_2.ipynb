# %%
#Q5
count=0
vote_bank={"CANDIATEA":{},"CANDIATEB":{},"CANDIATEC":{}}
print("CANDIATE A/nCANDIATE B/nCANDIATE C/n")
print("1.EMPLOYEE OF THE YEAR\n2.TEAM PLAYEROF THE YEAR\n3.INNOVATION AWARD")
voters = int(input("NUMBER OF VOTERS::"))
for  i in range(1,voters+1):
    candidate_name=input("ENTER CANDIATE NAME::")
    vote_category=int(input("ENTER VOTE CATEGORY::"))
    if candidate_name == "CANDIATEA":
        if vote_category==1:
            if vote_category not in vote_bank[candidate_name]:
                count=0
                count+=1
                vote_bank[candidate_name].update({vote_category:count})
                
            else:
                vote_bank[candidate_name][vote_category] += 1
        elif vote_category==2:
            if vote_category not in vote_bank[candidate_name]:
                count=0
                count+=1
                vote_bank[candidate_name].update({vote_category:count})
            else:
                vote_bank[candidate_name][vote_category] += 1
        elif vote_category==3:
            if vote_category not in vote_bank[candidate_name]:
                count=0
                count+=1
                vote_bank[candidate_name].update({vote_category:count})
            else:
                vote_bank[candidate_name][vote_category] += 1
    if candidate_name == "CANDIATEB":
        if vote_category==1:
            if vote_category not in vote_bank[candidate_name]:
                count=0
                count+=1
                vote_bank[candidate_name].update({vote_category:count})   
            else:
                vote_bank[candidate_name][vote_category] += 1
        elif vote_category==2:
            if vote_category not in vote_bank[candidate_name]:
                count=0
                count+=1
                vote_bank[candidate_name].update({vote_category:count})
            else:
                vote_bank[candidate_name][vote_category] += 1
        elif vote_category==3:
            if vote_category not in vote_bank[candidate_name]:
                count=0
                count+=1
                vote_bank[candidate_name].update({vote_category:count})
            else:
                vote_bank[candidate_name][vote_category] += 1
    if candidate_name == "CANDIATEC":
        if vote_category==1:
            if vote_category not in vote_bank[candidate_name]:
                count=0
                count+=1
                vote_bank[candidate_name].update({vote_category:count})
                
            else:
                vote_bank[candidate_name][vote_category] += 1
        elif vote_category==2:
            if vote_category not in vote_bank[candidate_name]:
                count=0
                count+=1
                vote_bank[candidate_name].update({vote_category:count})
            else:
                vote_bank[candidate_name][vote_category] += 1
        elif vote_category==3:
            if vote_category not in vote_bank[candidate_name]:
                count=0
                count+=1
                vote_bank[candidate_name].update({vote_category:count})
            else:
                vote_bank[candidate_name][vote_category] += 1
    print(vote_bank)
for candidate ,vote in vote_bank.items():
    print("CANDIDATE NAME : (UNDER CATEGORY : VOTES)==> {0}:{1}".format(candidate,vote))
# Out:
# CANDIATE A/nCANDIATE B/nCANDIATE C/n
# 1.EMPLOYEE OF THE YEAR
# 2.TEAM PLAYEROF THE YEAR
# 3.INNOVATION AWARD
# NUMBER OF VOTERS::5
# ENTER CANDIATE NAME::CANDIATEA
# ENTER VOTE CATEGORY::1
# {'CANDIATEA': {1: 1}, 'CANDIATEB': {}, 'CANDIATEC': {}}
# ENTER CANDIATE NAME::CANDIATEB
# ENTER VOTE CATEGORY::2
# {'CANDIATEA': {1: 1}, 'CANDIATEB': {2: 1}, 'CANDIATEC': {}}
# ENTER CANDIATE NAME::CANDIATEA
# ENTER VOTE CATEGORY::3
# {'CANDIATEA': {1: 1, 3: 1}, 'CANDIATEB': {2: 1}, 'CANDIATEC': {}}
# ENTER CANDIATE NAME::CANDIATEB
# ENTER VOTE CATEGORY::2
# {'CANDIATEA': {1: 1, 3: 1}, 'CANDIATEB': {2: 2}, 'CANDIATEC': {}}
# ENTER CANDIATE NAME::CANDIATEC
# ENTER VOTE CATEGORY::3
# {'CANDIATEA': {1: 1, 3: 1}, 'CANDIATEB': {2: 2}, 'CANDIATEC': {3: 1}}
# CANDIDATE NAME : (UNDER CATEGORY : VOTES)==> CANDIATEA:{1: 1, 3: 1}
# CANDIDATE NAME : (UNDER CATEGORY : VOTES)==> CANDIATEB:{2: 2}
# CANDIDATE NAME : (UNDER CATEGORY : VOTES)==> CANDIATEC:{3: 1}

# %%
#Q1
shoping_list = []
loop_start=input("DO YOU WANT TO continuey/n::")
print("1.ADD ITEMS\n2.REMOVE ITEMS\n3.DISPLAY LIST\n0.FOR FINAL LIST")
while(loop_start == "y" or loop_start == "Y"):
    choice = int(input("ENTER OPERATIONS::"))
    if choice == 1:
        item = input("ENTER ITEM::")
        shoping_list.append(item)
    elif choice == 2:
        item = input("ENTER ITEM::")
        shoping_list.remove(item)
    elif choice == 3:
        print(shoping_list)
    elif choice == 0:
        break
    else:
        print("ERROR")
    loop_start=input("DO YOU WANT TO continuey/n::")
print(shoping_list)
# Out:
# DO YOU WANT TO continuey/n::y
# 1.ADD ITEMS
# 2.REMOVE ITEMS
# 3.DISPLAY LIST
# 0.FOR FINAL LIST
# ENTER OPERATIONS::1
# ENTER ITEM::mango
# DO YOU WANT TO continuey/n::y
# ENTER OPERATIONS::1
# ENTER ITEM::fish
# DO YOU WANT TO continuey/n::y
# ENTER OPERATIONS::1
# ENTER ITEM::cocacola
# DO YOU WANT TO continuey/n::3
# ['mango', 'fish', 'cocacola']

# %%
#Q4
passward = "Asad173967"
if len(passward) >= 8:
    if passward.isdigit() == False:#becauseis digit return true when all str is number other wise false
        if passward.isalpha() == False:
            if passward.isupper() == False:
                print("strong passward")
            else:
                print("WEAK PASSWARD")
        else:
            print("WEAK PASSWARD")
    else:
            print("WEAK PASSWARD")      
else:
    print("WEAK PASSWARD")
# Out:
# strong passward

# %%
#Q3
repeat_word = {}
word_list = ["apple","banana","apple","orange","banana","grape","apple"]
count = 0
for i in range(len(word_list)):
    word = word_list[i]
    for j in word_list:
        if word == j:
            count+=1
    repeat_word.update({word:count})
    count = 0
